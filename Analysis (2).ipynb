# %%
# import data using pandas
import pandas as pd

data = pd.read_csv("iris.csv")
print(data)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# display first few rows of data set
df = pd.read_csv("iris.csv")
print(df.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# data types
df = pd.read_csv("iris.csv")
print("Data types:\n", df.dtypes)
# Out:
# Data types:
#  5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
# missing values
df = pd.read_csv("iris.csv")
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
# drop rows with missing values
df = pd.read_csv("iris.csv")
df_cleaned = df.dropna()
print(df_cleaned.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# fill missing values
df = pd.read_csv("iris.csv")
df_filled = df.fillna(3.2)
print(df_filled.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# Compute the basic statistics of the numerical columns
data.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# Groupings and mean
df = pd.read_csv("iris.csv")
grouped = df.groupby("Iris-setosa").mean()
print(grouped)
# Out:
#                       5.1       3.5       1.4       0.2
# Iris-setosa
# Iris-setosa      5.004082  3.416327  1.465306  0.244898
# Iris-versicolor  5.936000  2.770000  4.260000  1.326000
# Iris-virginica   6.588000  2.974000  5.552000  2.026000

# %%
# patterns or interesting findings
df = pd.read_csv("iris.csv")
correlation = df.corr(numeric_only=True)
print("Correlation matrix:\n", correlation)
# Out:
# Correlation matrix:
#            5.1       3.5       1.4       0.2
# 5.1  1.000000 -0.103784  0.871283  0.816971
# 3.5 -0.103784  1.000000 -0.415218 -0.350733
# 1.4  0.871283 -0.415218  1.000000  0.962314
# 0.2  0.816971 -0.350733  0.962314  1.000000

# %%
# line chart
graphs = data.value_counts("Iris-setosa")
graphs.plot()
# Out:
# <Axes: xlabel='Iris-setosa'>

# %%
# bar chart
import matplotlib.pyplot as plt
df = pd.read_csv("iris.csv")
avg_values = df.groupby("Iris-setosa")["3.5"].mean()
avg_values.plot(kind='bar', color='skyblue')
plt.plot(x,y)
plt.title("Iris value")
plt.xlabel("Iris-setosa")
plt.ylabel("average value of 3.5")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# histogram
df = pd.read_csv("iris.csv")

plt.hist(df["Iris-setosa"], bins=20, color='green', edgecolor='black')
plt.title("Distribution of Iris-setosa")
plt.xlabel("Iris-setosa")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# scatter plot
df = pd.read_csv("iris.csv")
plt.scatter(df["Iris-setosa"], df["5.1"], color='purple', alpha=0.7)
plt.title("Iris-setosa vs. 5.1 column")
plt.xlabel("Iris-setosa")
plt.ylabel("5.1 column")
plt.grid(False)
plt.tight_layout()
plt.show()
